# %% [markdown]
# # Aula 2

# %% [markdown]
# ## Customizando nossas visualizações

# %% [markdown]
# ### Importando e pré processando dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('monitoramento_tempo.csv')
df['data'] = pd.to_datetime(df['data'])
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                data
# 0       Domingo 2012-10-01 12:00:00
# 1       Domingo 2012-10-01 13:00:00
# 2       Domingo 2012-10-01 14:00:00
# 3       Domingo 2012-10-01 15:00:00
# 4       Domingo 2012-10-01 16:00:00

# %% [markdown]
# ### Relembrando aula anterior

# %%
# Ultimo grafico da aula passada
fig = plt.figure(figsize=(12, 5))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color='green')

eixo.set_title('Temperatura no momento', fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=15)
eixo.set_xlabel('Data',fontsize=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)

# %% [markdown]
# ### Alterando o tamanho da linha

# %%
fig = plt.figure(figsize=(12, 5))
eixo = fig.add_axes([0, 0, 1, 1])
# lw siginifica line width
eixo.plot(df['data'], df['temperatura'], color='g',lw=4)

eixo.set_title('Temperatura no momento', fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=15)
eixo.set_xlabel('Data',fontsize=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)

# %%
fig = plt.figure(figsize=(12, 5))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color='g',lw=.4)

eixo.set_title('Temperatura no momento', fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=15)
eixo.set_xlabel('Data',fontsize=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)

# %% [markdown]
# ### Alterando o estilo da linha

# %%
fig = plt.figure(figsize=(12, 5))
eixo = fig.add_axes([0, 0, 1, 1])
# ls siginifica line style
eixo.plot(df['data'], df['temperatura'], color='g',ls='dotted')

eixo.set_title('Temperatura no momento', fontsize=20)
eixo.set_ylabel('Temperatura',fontsize=15)
eixo.set_xlabel('Data',fontsize=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)

# %% [markdown]
# ### Definindo limites x

# %%
import datetime

# %%
fig = plt.figure(figsize=(12, 5))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color='g')

eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo.set_title('Temperatura em 2014', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=15)
eixo.set_xlabel('Data', fontsize=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)

# %% [markdown]
# ### Adiconando marcadores

# %%
fig = plt.figure(figsize=(12, 5))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color='g', marker='o')

eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo.set_title('Temperatura em 2014', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=15)
eixo.set_xlabel('Data', fontsize=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)

# %% [markdown]
# ### Adicionando a grid

# %%
fig = plt.figure(figsize=(12, 5))
eixo = fig.add_axes([0, 0, 1, 1])
eixo.plot(df['data'], df['temperatura'], color='g')

eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo.set_title('Temperatura em 2014', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=15)
eixo.set_xlabel('Data', fontsize=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)
eixo.grid(True)

# %% [markdown]
# ### Eixo dentro do eixo

# %%
fig = plt.figure(figsize=(12, 5))

eixo = fig.add_axes([0, 0, 1, 1])
eixo_2 = fig.add_axes([.1, .5, .4, .4])

eixo.set_title('Temperatura em 2014', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=15)
eixo.set_xlabel('Data', fontsize=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)

# %% [markdown]
# ### Adicionando Pad

# %%
fig = plt.figure(figsize=(12, 5))

eixo = fig.add_axes([0, 0, 1, 1])
eixo_2 = fig.add_axes([.1, .5, .4, .4])

eixo.grid(True)
eixo.plot(df['data'],df['temperatura'], color='g')
eixo.set_title('Temperatura em 2014', fontsize=20, pad=15)
eixo.legend(['Temperatura'], loc='best', fontsize=12)

# %% [markdown]
# ### Adicionando dados em eixo dentro do eixo, estilizando e adicionando limites

# %%
fig = plt.figure(figsize=(12, 5))

eixo = fig.add_axes([0, 0, 1, 1])
eixo_2 = fig.add_axes([.7, .66, .3, .25])

eixo.grid(True)
eixo.plot(df['data'],df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo.set_title('Temperatura em 2014', fontsize=20, pad=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)
eixo.set_ylabel('Temperatura', fontsize=15)
eixo.set_xlabel('Data', fontsize=15)


eixo_2.grid(True)
eixo_2.plot(df['data'], df['temperatura'], color='b')
eixo_2.set_title('Temperatura no momento', fontsize=10, pad=15)
eixo_2.legend(['Temperatura'], loc='best', fontsize=8)
eixo_2.set_ylabel('Temperatura', fontsize=8)
eixo_2.set_xlabel('Data', fontsize=8)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ### Alterando periodo escolhido
# Também é alterado o grafico menor que agora representa o ano de 2014 e foi reestilizado

# %%
fig = plt.figure(figsize=(12, 5))

eixo = fig.add_axes([0, 0, 1, 1])
eixo_2 = fig.add_axes([.6, .66, .4, .3])

eixo.grid(True)
eixo.plot(df['data'],df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2014, 6, 1))
eixo.set_title('Temperatura em maio/2014', fontsize=20, pad=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)
eixo.set_ylabel('Temperatura', fontsize=15)
eixo.set_xlabel('Data', fontsize=15)


eixo_2.grid(True)
eixo_2.plot(df['data'], df['temperatura'], color='b')
eixo_2.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo_2.set_title('Temperatura em 2014', fontsize=10, pad=15)
eixo_2.legend(['Temperatura'], loc='best', fontsize=8)
eixo_2.set_ylabel('Temperatura', fontsize=8)
eixo_2.set_xlabel('Data', fontsize=8)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ### Adicionando limites y

# %%
fig = plt.figure(figsize=(12, 5))

eixo = fig.add_axes([0, 0, 1, 1])
eixo_2 = fig.add_axes([.6, .66, .4, .3])

eixo.grid(True)
eixo.plot(df['data'],df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2014, 6, 1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura em maio/2014', fontsize=20, pad=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)
eixo.set_ylabel('Temperatura', fontsize=15)
eixo.set_xlabel('Data', fontsize=15)


eixo_2.grid(True)
eixo_2.plot(df['data'], df['temperatura'], color='b')
eixo_2.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo_2.set_title('Temperatura em 2014', fontsize=10, pad=15)
eixo_2.legend(['Temperatura'], loc='best', fontsize=8)
eixo_2.set_ylabel('Temperatura', fontsize=8)
eixo_2.set_xlabel('Data', fontsize=8)
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ### Adicionando filtro para destaque do grafico menor

# %%
fig = plt.figure(figsize=(12, 5))

eixo = fig.add_axes([0, 0, 1, 1])
eixo_2 = fig.add_axes([.6, .66, .4, .3])

eixo.grid(True)
eixo.plot(df['data'],df['temperatura'], color='g')
eixo.set_xlim(datetime.datetime(2014, 5, 1), datetime.datetime(2014, 6, 1))
eixo.set_ylim(270, 320)
eixo.set_title('Temperatura em maio/2014', fontsize=20, pad=15)
eixo.legend(['Temperatura'], loc='lower right', fontsize=12)
eixo.set_ylabel('Temperatura', fontsize=15)
eixo.set_xlabel('Data', fontsize=15)

# Criando os filtros  
azul_esquerda = df['data'] < datetime.datetime(2014, 5, 1)
azul_direita = df['data'] > datetime.datetime(2014, 6, 1)


eixo_2.grid(True)
# A cor foi alterada para que possamos usar os filtros como parte azul
eixo_2.plot(df['data'], df['temperatura'], color='g')

# Aplicando os filtros
# Usamos os filtros e selecionamos os campos dentro dos dataframes resultantes
eixo_2.plot(df[azul_esquerda]['data'], df[azul_esquerda]['temperatura'], color='b')
eixo_2.plot(df[azul_direita]['data'], df[azul_direita]['temperatura'], color='b')

eixo_2.set_xlim(datetime.datetime(2014, 1, 1), datetime.datetime(2015, 1, 1))
eixo_2.set_title('Temperatura em 2014', fontsize=10, pad=15)
eixo_2.legend(['Temperatura'], loc='best', fontsize=8)
eixo_2.set_ylabel('Temperatura', fontsize=8)
eixo_2.set_xlabel('Data', fontsize=8)
# Out:
# Text(0.5, 0, 'Data')
